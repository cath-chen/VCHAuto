# %%
import pandas as pd
hs = pd.read_csv('KEVIN USE - W24 Week 3 & 4 Health Sites Sign-ups (Responses) - Form Responses 1.csv') # enter csv here
hs['Full Name'] = hs['Full Name'].str.upper()
hs
# Out:
#              Timestamp         Full Name  University ID #  Phone Number  \
# 0   1/23/2024 20:01:07      ERIKA NGUYEN        805813042    8604619848
# 1   1/23/2024 20:04:27      NEHA CHANDRA        805512143    9163371808
# 2   1/23/2024 20:04:41      DAVID NGUYEN        106067079    6696664831
# 3   1/23/2024 20:04:42      THINH H TRAN          6042046    4088367590
# 4   1/23/2024 20:04:43      ADELE NGUYEN        905770909    5107097369
# 5   1/23/2024 20:04:43    ANDREWTRUNG LE        305575996    7143948411
# 6   1/23/2024 20:04:55        JAMES PHAM        305943183    4089151007
# 7   1/23/2024 20:04:55      HANNAH HOANG        605497266    9518071142
# 8   1/23/2024 20:04:58        KELLY TRAN          5512444    9093447083
# 9   1/23/2024 20:05:00          NANCY LA        205714498    7142603561
# 10  1/23/2024 20:05:07      BRANDON PHAM        606069472    4086696577
# 11  1/23/2024 20:05:14         MEGAN VAN        506200632    6262650824
# 12  1/23/2024 20:05:15       ANDY NGUYEN        705971800    7149338708
# 13  1/23/2024 20:05:20       DREW NGUYEN        105702698    7146582296
# 14  1/23/2024 20:05:20  MI (MIMI) NGUYEN        806220681    4087240753
# 15  1/23/2024 20:05:21       ANDY NGUYEN        605970194  916-201-4073
# 16  1/23/2024 20:05:29        ANSON PHAM        806166603    7148736313
# 17  1/23/2024 20:05:34        YUKI DUONG        805721033    7603365024
# 18  1/23/2024 20:05:34        KELLY TANG        805943213    6267081500
# 19  1/23/2024 20:05:46            NATHAN        806177319    7144678067
# 20  1/23/2024 20:05:49      TRACY NGUYEN        606002170    6577229323
# 21  1/23/2024 20:05:53       BRIAN PHUNG        606156799  714-348-2747
# 22  1/23/2024 20:06:31  ADARSH CHILKUNDA        705765640    7472414854
# 23  1/23/2024 20:06:40   JAZMIN A CHAVEZ        806139695    7147603752
# 24  1/23/2024 20:06:43       TINA NGUYEN        706155775    7143053640
# 25  1/23/2024 20:06:48     STELLA NGUYEN        305587372    7142623942
# 26  1/23/2024 20:07:13  BEATRICE O’BRIEN        505935592    4157205759
# 27  1/23/2024 20:07:59    GERARDO ORTEGA        705579394    9097893357
# 28  1/23/2024 20:09:10          DYLAN DO        505921627    7149105847
# 29  1/23/2024 20:28:32   MATTHEW NGUYEN         905799069  714 696 4388
#
#                          Email Year  \
# 0       Erikanguyen@g.ucla.edu  3rd
# 1     nehachandra531@gmail.com  4th
# 2      Csdavidnguyen@gmail.com  4th
# 3      Thinhtran711@g.ucla.edu  4th
# 4       adeleunguyen@gmail.com  3rd
# 5      andrewnhe2302@gmail.com  4th
# 6          jamesut90@gmail.com  2nd
# 7      hannahkhoang@g.ucla.edu  4th
# 8            kptran20@ucla.edu  4th
# 9             Nxncyla@ucla.edu  3rd
# 10  brandon.pham2022@gmail.com  2nd
# 11           mvan04@g.ucla.edu  1st
# 12        andyhn1118@gmail.com  2nd
# 13       aknguyen21@g.ucla.edu  3rd
# 14        mitrangram@gmail.com  1st
# 15           andyn4@g.ucla.edu  2nd
# 16         ansonbpham@ucla.edu  1st
# 17          yuki133@g.ucla.edu  3rd
# 18      kellytang.co@gmail.com  2nd
# 19          23ndang3@gmail.com  1st
# 20           trayseee@ucla.edu  2nd
# 21      brianbruin2@g.ucla.edu  1st
# 22          adroyalz@gmail.com  3rd
# 23     jazminchavez@g.ucla.edu  1st
# 24          tn650220@gmail.com  1st
# 25   stellanguyen02@g.ucla.edu  4th
# 26          beaobrien@ucla.edu  2nd
# 27  ortegagerardo20@g.ucla.edu  4th
# 28          dylando@g.ucla.edu  2nd
# 29     mattnguyen03@g.ucla.edu  3rd
#
#        What Health Sites would you be available for?   \
# 0                      January 28 (Asian Garden Mall)
# 1                          February 4 (Del Amo Plaza)
# 2   January 28 (Asian Garden Mall), February 4 (De...
# 3                      January 28 (Asian Garden Mall)
# 4   January 28 (Asian Garden Mall), February 4 (De...
# 5                          February 4 (Del Amo Plaza)
# 6                      January 28 (Asian Garden Mall)
# 7                      January 28 (Asian Garden Mall)
# 8                      January 28 (Asian Garden Mall)
# 9                          February 4 (Del Amo Plaza)
# 10                     January 28 (Asian Garden Mall)
# 11                     January 28 (Asian Garden Mall)
# 12                     January 28 (Asian Garden Mall)
# 13                     January 28 (Asian Garden Mall)
# 14                         February 4 (Del Amo Plaza)
# 15                         February 4 (Del Amo Plaza)
# 16                     January 28 (Asian Garden Mall)
# 17                         February 4 (Del Amo Plaza)
# 18                     January 28 (Asian Garden Mall)
# 19  January 28 (Asian Garden Mall), February 4 (De...
# 20                     January 28 (Asian Garden Mall)
# 21  January 28 (Asian Garden Mall), February 4 (De...
# 22                         February 4 (Del Amo Plaza)
# 23                         February 4 (Del Amo Plaza)
# 24                     January 28 (Asian Garden Mall)
# 25                     January 28 (Asian Garden Mall)
# 26                         February 4 (Del Amo Plaza)
# 27                         February 4 (Del Amo Plaza)
# 28                         February 4 (Del Amo Plaza)
# 29                     January 28 (Asian Garden Mall)
#
#    Do you speak Vietnamese?    Do you speak Spanish?  \
# 0   Yes, but conversational  Yes, but conversational
# 1                        No  Yes, but conversational
# 2          Yes, I am fluent  Yes, but conversational
# 3          Yes, I am fluent                       No
# 4   Yes, but conversational                       No
# 5   Yes, but conversational                       No
# 6   Yes, but conversational                       No
# 7          Yes, I am fluent                       No
# 8   Yes, but conversational                       No
# 9          Yes, I am fluent                       No
# 10  Yes, but conversational  Yes, but conversational
# 11  Yes, but conversational                       No
# 12  Yes, but conversational                       No
# 13  Yes, but conversational  Yes, but conversational
# 14         Yes, I am fluent  Yes, but conversational
# 15  Yes, but conversational                       No
# 16  Yes, but conversational                       No
# 17                       No  Yes, but conversational
# 18  Yes, but conversational                       No
# 19         Yes, I am fluent  Yes, but conversational
# 20         Yes, I am fluent  Yes, but conversational
# 21  Yes, but conversational  Yes, but conversational
# 22                       No  Yes, but conversational
# 23                       No         Yes, I am fluent
# 24  Yes, but conversational                       No
# 25  Yes, but conversational                       No
# 26                       No         Yes, I am fluent
# 27                       No         Yes, I am fluent
# 28         Yes, I am fluent                       No
# 29  Yes, but conversational                       No
#
#      Do you need a ride from UCLA? Are you Hypertension trained?  \
# 0                              Yes                            No
# 1                              Yes                           Yes
# 2   No, I can provide my own ride.                           Yes
# 3   No, I can provide my own ride.                           Yes
# 4                              Yes                           Yes
# 5   No, I can provide my own ride.                           Yes
# 6                              Yes                            No
# 7                              Yes                           Yes
# 8                              Yes                           Yes
# 9                              Yes                           Yes
# 10                             Yes                            No
# 11                             Yes                           Yes
# 12                             Yes                           Yes
# 13  No, I can provide my own ride.                           Yes
# 14                             Yes                           Yes
# 15                             Yes                           Yes
# 16  No, I can provide my own ride.                            No
# 17                             Yes                           Yes
# 18                             Yes                            No
# 19  No, I can provide my own ride.                            No
# 20  No, I can provide my own ride.                           Yes
# 21                             Yes                           Yes
# 22                             Yes                            No
# 23                             Yes                           Yes
# 24                             Yes                           Yes
# 25  No, I can provide my own ride.                            No
# 26  No, I can provide my own ride.                           Yes
# 27                             Yes                           Yes
# 28                             Yes                           Yes
# 29  No, I can provide my own ride.                           Yes
#
#                              Are you HIPAA Certified?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13                                                Yes
# 14  No, but I can send vchbruins@gmail.com the cer...
# 15                                                Yes
# 16  No, but I can send vchbruins@gmail.com the cer...
# 17                                                Yes
# 18                                                Yes
# 19  No, but I can send vchbruins@gmail.com the cer...
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25                                                Yes
# 26                                                Yes
# 27                                                Yes
# 28                                                Yes
# 29                                                Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                                 Yes
# 1                                          Of course!
# 2                                                 Yes
# 3                                          Of course!
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                         Of course!
# 19                                         Of course!
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25                                         Of course!
# 26                                                Yes
# 27                                                Yes
# 28                                                Yes
# 29                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 0                                              Medium
# 1                               I already have a polo
# 2                               I already have a polo
# 3                               I already have a polo
# 4                               I already have a polo
# 5                               I already have a polo
# 6                               I already have a polo
# 7                                               Small
# 8                               I already have a polo
# 9                               I already have a polo
# 10                              I already have a polo
# 11                              I already have a polo
# 12                              I already have a polo
# 13                              I already have a polo
# 14                                              Small
# 15                              I already have a polo
# 16                                              Large
# 17                                             Medium
# 18                              I already have a polo
# 19                              I already have a polo
# 20                              I already have a polo
# 21                              I already have a polo
# 22                              I already have a polo
# 23                                             Medium
# 24                              I already have a polo
# 25                              I already have a polo
# 26                              I already have a polo
# 27                              I already have a polo
# 28                              I already have a polo
# 29                              I already have a polo

# %%
# og df = hs

# new empty df with the same columns as the og df
agm_invites = pd.DataFrame(columns=hs.columns)

# function to select people for viet and hypertension and move to new df
def select_volunteers_agm_fluent(row):
    global hs, agm_invites
    
    date = row['What Health Sites would you be available for? ']
    vietnamese_proficiency = row['Do you speak Vietnamese?']
    
    # check fluent
    if date in ['January 28 (Asian Garden Mall)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if vietnamese_proficiency in ['Yes, I am fluent']:
            if len(agm_invites[agm_invites['Do you speak Vietnamese?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
                agm_invites = agm_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)
            
def select_volunteers_agm_conversational(row):
    global hs, agm_invites
    
    date = row['What Health Sites would you be available for? ']
    vietnamese_proficiency = row['Do you speak Vietnamese?']
    
    # check conversational + hypertension
    if date in ['January 28 (Asian Garden Mall)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if vietnamese_proficiency in ['Yes, but conversational']:
            if len(agm_invites[agm_invites['Do you speak Vietnamese?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
                agm_invites = agm_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)
                
def select_volunteers_agm_hypertension(row):
    global hs, agm_invites
    
    date = row['What Health Sites would you be available for? ']
    hypertension_trained = row['Are you Hypertension trained?']
    
    if date in ['January 28 (Asian Garden Mall)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if hypertension_trained in ['Yes']:
            if len(agm_invites[agm_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
                agm_invites = agm_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)  


# function to randomly select remaining people to fill 10 people from ucla and 6 people from home for agm
def select_random_agm_ucla(row):
    global hs, agm_invites
    
    date = row['What Health Sites would you be available for? ']
    location = row['Do you need a ride from UCLA?']
    
    if date in ['January 28 (Asian Garden Mall)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if location in ['Yes']:
            if len(agm_invites[agm_invites['Do you need a ride from UCLA?'].isin(['Yes'])]) < 9:
                agm_invites = agm_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)
    
def select_random_agm_home(row):
    global hs, agm_invites
    
    date = row['What Health Sites would you be available for? ']
    location = row['Do you need a ride from UCLA?']
            
    if date in ['January 28 (Asian Garden Mall)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if location in ['No, I can provide my own ride.']:
            if len(agm_invites[agm_invites['Do you need a ride from UCLA?'].isin(['No, I can provide my own ride.'])]) < 6:
                agm_invites = agm_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)

# %%
# new empty df with the same columns as the og df
dap_invites = pd.DataFrame(columns=hs.columns)

# function to select people for spanish and hypertension and move to new df
def select_volunteers_dap_fluent(row):
    global hs, dap_invites
    
    date = row['What Health Sites would you be available for? ']
    spanish_proficiency = row['Do you speak Spanish?']
    
    # check fluent
    if date in ['February 4 (Del Amo Plaza)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if spanish_proficiency in ['Yes, I am fluent']:
            if len(dap_invites[dap_invites['Do you speak Spanish?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
                dap_invites = dap_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)
    
def select_volunteers_dap_conversational(row):
    global hs, dap_invites
    
    date = row['What Health Sites would you be available for? ']
    spanish_proficiency = row['Do you speak Spanish?']
    
    # check conversational + hypertension
    if date in ['February 4 (Del Amo Plaza)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if spanish_proficiency in ['Yes, but conversational']:
            if len(dap_invites[dap_invites['Do you speak Spanish?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
                dap_invites = dap_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)
                
def select_volunteers_dap_hypertension(row):
    global hs, dap_invites
    
    date = row['What Health Sites would you be available for? ']
    hypertension_trained = row['Are you Hypertension trained?']
    
    if date in ['February 4 (Del Amo Plaza)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if hypertension_trained in ['Yes']:
            if len(dap_invites[dap_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
                dap_invites = dap_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)  
            
# function to randomly select remaining people to fill 10 people from ucla and 6 people from home for dap
def select_random_dap_ucla(row):
    global hs, dap_invites
    
    date = row['What Health Sites would you be available for? ']
    location = row['Do you need a ride from UCLA?']
    
    if date in ['February 4 (Del Amo Plaza)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if location in ['Yes']:
            if len(dap_invites[dap_invites['Do you need a ride from UCLA?'].isin(['Yes'])]) < 9:
                dap_invites = dap_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)
                
def select_random_dap_home(row):
    global hs, dap_invites
    
    date = row['What Health Sites would you be available for? ']
    location = row['Do you need a ride from UCLA?']        
    

    if date in ['February 4 (Del Amo Plaza)', 'January 28 (Asian Garden Mall), February 4 (Del Amo Plaza)']:
        if location in ['No, I can provide my own ride.']:
            if len(dap_invites[dap_invites['Do you need a ride from UCLA?'].isin(['No, I can provide my own ride.'])]) < 6:
                dap_invites = dap_invites._append(row, ignore_index=True)
                hs = hs.drop(index=row.name)

# %%
# Loop through rows in the original dataframe for dap
for index, row in hs.iterrows():
    select_volunteers_dap_fluent(row)
    
if len(dap_invites[dap_invites['Do you speak Spanish?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3:
    for index, row in hs.iterrows():
        select_volunteers_dap_conversational(row)

if len(dap_invites[dap_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
    for index, row in hs.iterrows():
        select_volunteers_dap_hypertension(row)
    
for index, row in hs.iterrows():
    select_random_dap_ucla(row)
    
for index, row in hs.iterrows():
    select_random_dap_home(row)

# %%
dap_invites
dap_invites = dap_invites.sort_values('Do you need a ride from UCLA?')

# %%
dap_invites
# Out:
#              Timestamp         Full Name University ID #  Phone Number  \
# 1   1/23/2024 20:07:13  BEATRICE O’BRIEN       505935592    4157205759
# 10  1/23/2024 20:04:41      DAVID NGUYEN       106067079    6696664831
# 11  1/23/2024 20:04:43    ANDREWTRUNG LE       305575996    7143948411
# 12  1/23/2024 20:05:46            NATHAN       806177319    7144678067
# 0   1/23/2024 20:06:40   JAZMIN A CHAVEZ       806139695    7147603752
# 2   1/23/2024 20:07:59    GERARDO ORTEGA       705579394    9097893357
# 3   1/23/2024 20:04:27      NEHA CHANDRA       805512143    9163371808
# 4   1/23/2024 20:04:43      ADELE NGUYEN       905770909    5107097369
# 5   1/23/2024 20:05:00          NANCY LA       205714498    7142603561
# 6   1/23/2024 20:05:20  MI (MIMI) NGUYEN       806220681    4087240753
# 7   1/23/2024 20:05:21       ANDY NGUYEN       605970194  916-201-4073
# 8   1/23/2024 20:05:34        YUKI DUONG       805721033    7603365024
# 9   1/23/2024 20:05:53       BRIAN PHUNG       606156799  714-348-2747
#
#                          Email Year  \
# 1           beaobrien@ucla.edu  2nd
# 10     Csdavidnguyen@gmail.com  4th
# 11     andrewnhe2302@gmail.com  4th
# 12          23ndang3@gmail.com  1st
# 0      jazminchavez@g.ucla.edu  1st
# 2   ortegagerardo20@g.ucla.edu  4th
# 3     nehachandra531@gmail.com  4th
# 4       adeleunguyen@gmail.com  3rd
# 5             Nxncyla@ucla.edu  3rd
# 6         mitrangram@gmail.com  1st
# 7            andyn4@g.ucla.edu  2nd
# 8           yuki133@g.ucla.edu  3rd
# 9       brianbruin2@g.ucla.edu  1st
#
#        What Health Sites would you be available for?   \
# 1                          February 4 (Del Amo Plaza)
# 10  January 28 (Asian Garden Mall), February 4 (De...
# 11                         February 4 (Del Amo Plaza)
# 12  January 28 (Asian Garden Mall), February 4 (De...
# 0                          February 4 (Del Amo Plaza)
# 2                          February 4 (Del Amo Plaza)
# 3                          February 4 (Del Amo Plaza)
# 4   January 28 (Asian Garden Mall), February 4 (De...
# 5                          February 4 (Del Amo Plaza)
# 6                          February 4 (Del Amo Plaza)
# 7                          February 4 (Del Amo Plaza)
# 8                          February 4 (Del Amo Plaza)
# 9   January 28 (Asian Garden Mall), February 4 (De...
#
#    Do you speak Vietnamese?    Do you speak Spanish?  \
# 1                        No         Yes, I am fluent
# 10         Yes, I am fluent  Yes, but conversational
# 11  Yes, but conversational                       No
# 12         Yes, I am fluent  Yes, but conversational
# 0                        No         Yes, I am fluent
# 2                        No         Yes, I am fluent
# 3                        No  Yes, but conversational
# 4   Yes, but conversational                       No
# 5          Yes, I am fluent                       No
# 6          Yes, I am fluent  Yes, but conversational
# 7   Yes, but conversational                       No
# 8                        No  Yes, but conversational
# 9   Yes, but conversational  Yes, but conversational
#
#      Do you need a ride from UCLA? Are you Hypertension trained?  \
# 1   No, I can provide my own ride.                           Yes
# 10  No, I can provide my own ride.                           Yes
# 11  No, I can provide my own ride.                           Yes
# 12  No, I can provide my own ride.                            No
# 0                              Yes                           Yes
# 2                              Yes                           Yes
# 3                              Yes                           Yes
# 4                              Yes                           Yes
# 5                              Yes                           Yes
# 6                              Yes                           Yes
# 7                              Yes                           Yes
# 8                              Yes                           Yes
# 9                              Yes                           Yes
#
#                              Are you HIPAA Certified?  \
# 1                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12  No, but I can send vchbruins@gmail.com the cer...
# 0                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6   No, but I can send vchbruins@gmail.com the cer...
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 1                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                         Of course!
# 0                                                 Yes
# 2                                                 Yes
# 3                                          Of course!
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 1                               I already have a polo
# 10                              I already have a polo
# 11                              I already have a polo
# 12                              I already have a polo
# 0                                              Medium
# 2                               I already have a polo
# 3                               I already have a polo
# 4                               I already have a polo
# 5                               I already have a polo
# 6                                               Small
# 7                               I already have a polo
# 8                                              Medium
# 9                               I already have a polo

# %%
# Loop through rows in the original dataframe for agm
for index, row in hs.iterrows():
    select_volunteers_agm_fluent(row)
    
if len(agm_invites[agm_invites['Do you speak Vietnamese?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3:
    for index, row in hs.iterrows():
        select_volunteers_agm_conversational(row)

if len(agm_invites[agm_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
    for index, row in hs.iterrows():
        select_volunteers_agm_hypertension(row)
    
for index, row in hs.iterrows():
    select_random_agm_ucla(row)

for index, row in hs.iterrows():
    select_random_agm_home(row)

# %%
agm_invites
agm_invites = agm_invites.sort_values('Do you need a ride from UCLA?')

# %%
agm_invites
# Out:
#              Timestamp        Full Name University ID #  Phone Number  \
# 0   1/23/2024 20:04:42     THINH H TRAN         6042046    4088367590
# 2   1/23/2024 20:05:49     TRACY NGUYEN       606002170    6577229323
# 11  1/23/2024 20:05:20      DREW NGUYEN       105702698    7146582296
# 12  1/23/2024 20:05:29       ANSON PHAM       806166603    7148736313
# 13  1/23/2024 20:06:48    STELLA NGUYEN       305587372    7142623942
# 14  1/23/2024 20:28:32  MATTHEW NGUYEN        905799069  714 696 4388
# 1   1/23/2024 20:04:55     HANNAH HOANG       605497266    9518071142
# 3   1/23/2024 20:01:07     ERIKA NGUYEN       805813042    8604619848
# 4   1/23/2024 20:04:55       JAMES PHAM       305943183    4089151007
# 5   1/23/2024 20:04:58       KELLY TRAN         5512444    9093447083
# 6   1/23/2024 20:05:07     BRANDON PHAM       606069472    4086696577
# 7   1/23/2024 20:05:14        MEGAN VAN       506200632    6262650824
# 8   1/23/2024 20:05:15      ANDY NGUYEN       705971800    7149338708
# 9   1/23/2024 20:05:34       KELLY TANG       805943213    6267081500
# 10  1/23/2024 20:06:43      TINA NGUYEN       706155775    7143053640
#
#                          Email Year  \
# 0      Thinhtran711@g.ucla.edu  4th
# 2            trayseee@ucla.edu  2nd
# 11       aknguyen21@g.ucla.edu  3rd
# 12         ansonbpham@ucla.edu  1st
# 13   stellanguyen02@g.ucla.edu  4th
# 14     mattnguyen03@g.ucla.edu  3rd
# 1      hannahkhoang@g.ucla.edu  4th
# 3       Erikanguyen@g.ucla.edu  3rd
# 4          jamesut90@gmail.com  2nd
# 5            kptran20@ucla.edu  4th
# 6   brandon.pham2022@gmail.com  2nd
# 7            mvan04@g.ucla.edu  1st
# 8         andyhn1118@gmail.com  2nd
# 9       kellytang.co@gmail.com  2nd
# 10          tn650220@gmail.com  1st
#
#    What Health Sites would you be available for?  Do you speak Vietnamese?  \
# 0                  January 28 (Asian Garden Mall)         Yes, I am fluent
# 2                  January 28 (Asian Garden Mall)         Yes, I am fluent
# 11                 January 28 (Asian Garden Mall)  Yes, but conversational
# 12                 January 28 (Asian Garden Mall)  Yes, but conversational
# 13                 January 28 (Asian Garden Mall)  Yes, but conversational
# 14                 January 28 (Asian Garden Mall)  Yes, but conversational
# 1                  January 28 (Asian Garden Mall)         Yes, I am fluent
# 3                  January 28 (Asian Garden Mall)  Yes, but conversational
# 4                  January 28 (Asian Garden Mall)  Yes, but conversational
# 5                  January 28 (Asian Garden Mall)  Yes, but conversational
# 6                  January 28 (Asian Garden Mall)  Yes, but conversational
# 7                  January 28 (Asian Garden Mall)  Yes, but conversational
# 8                  January 28 (Asian Garden Mall)  Yes, but conversational
# 9                  January 28 (Asian Garden Mall)  Yes, but conversational
# 10                 January 28 (Asian Garden Mall)  Yes, but conversational
#
#       Do you speak Spanish?   Do you need a ride from UCLA?  \
# 0                        No  No, I can provide my own ride.
# 2   Yes, but conversational  No, I can provide my own ride.
# 11  Yes, but conversational  No, I can provide my own ride.
# 12                       No  No, I can provide my own ride.
# 13                       No  No, I can provide my own ride.
# 14                       No  No, I can provide my own ride.
# 1                        No                             Yes
# 3   Yes, but conversational                             Yes
# 4                        No                             Yes
# 5                        No                             Yes
# 6   Yes, but conversational                             Yes
# 7                        No                             Yes
# 8                        No                             Yes
# 9                        No                             Yes
# 10                       No                             Yes
#
#    Are you Hypertension trained?  \
# 0                            Yes
# 2                            Yes
# 11                           Yes
# 12                            No
# 13                            No
# 14                           Yes
# 1                            Yes
# 3                             No
# 4                             No
# 5                            Yes
# 6                             No
# 7                            Yes
# 8                            Yes
# 9                             No
# 10                           Yes
#
#                              Are you HIPAA Certified?  \
# 0                                                 Yes
# 2                                                 Yes
# 11                                                Yes
# 12  No, but I can send vchbruins@gmail.com the cer...
# 13                                                Yes
# 14                                                Yes
# 1                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                          Of course!
# 2                                                 Yes
# 11                                                Yes
# 12                                                Yes
# 13                                         Of course!
# 14                                                Yes
# 1                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                          Of course!
# 10                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 0                               I already have a polo
# 2                               I already have a polo
# 11                              I already have a polo
# 12                                              Large
# 13                              I already have a polo
# 14                              I already have a polo
# 1                                               Small
# 3                                              Medium
# 4                               I already have a polo
# 5                               I already have a polo
# 6                               I already have a polo
# 7                               I already have a polo
# 8                               I already have a polo
# 9                               I already have a polo
# 10                              I already have a polo

# %%
hs
# Out:
#              Timestamp         Full Name  University ID # Phone Number  \
# 22  1/23/2024 20:06:31  ADARSH CHILKUNDA        705765640   7472414854
# 28  1/23/2024 20:09:10          DYLAN DO        505921627   7149105847
#
#                  Email Year What Health Sites would you be available for?   \
# 22  adroyalz@gmail.com  3rd                     February 4 (Del Amo Plaza)
# 28  dylando@g.ucla.edu  2nd                     February 4 (Del Amo Plaza)
#
#    Do you speak Vietnamese?    Do you speak Spanish?  \
# 22                       No  Yes, but conversational
# 28         Yes, I am fluent                       No
#
#    Do you need a ride from UCLA? Are you Hypertension trained?  \
# 22                           Yes                            No
# 28                           Yes                           Yes
#
#    Are you HIPAA Certified?  \
# 22                      Yes
# 28                      Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 22                                                Yes
# 28                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 22                              I already have a polo
# 28                              I already have a polo

# %%
hs = hs.sort_values('What Health Sites would you be available for? ')
hs = pd.concat([agm_invites, dap_invites, hs])
hs.to_csv('week3_and4_hs_final.csv') #name the file
