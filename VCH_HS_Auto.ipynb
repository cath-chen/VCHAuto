# %%
# import pandas as pd
# week1_hs = pd.read_csv('./week1_hs_test.csv')
# week1_hs['Full Name'] = week1_hs['Full Name'].str.upper()
# # week1_hs['Phone Number'] = week1_hs['Phone Number'].replace('-', '', regex=True).astype(int)
# #print(week1_hs.columns.tolist())
# week1_hs

# %%
# SpanishProficiency = week1_hs["Do you speak Spanish?"]
# VietnameseProficiency = week1_hs["Do you speak Vietnamese?"]
# # print(SpanishProficiency)
# # print(VietnameseProficiency)

# %%
# week1_sat = week1_hs[week1_hs['What Health Sites would you be available for? '].isin(['November 18 (Asian Garden Mall)', 'November 18 (Asian Garden Mall), November 19 (Santa Ana Plaza)'])]
# week1_sun = week1_hs[week1_hs['What Health Sites would you be available for? '].isin(['November 19 (Santa Ana Plaza)', 'November 18 (Asian Garden Mall), November 19 (Santa Ana Plaza)'])]
# week1_sat

# CAN I MAKE THIS CELL APPLICABLE TO ALL SITES?
# INSTEAD OF SAT/SUN, MAKE AGM/DAP

# %%
# week1_sun

# %%
# # Criteria for selection

# criteria_viet = 3 # At least 3 people fluent or conversational in Vietnamese
# #criteria_spanish = 3  # At least 3 people fluent or conversational in Spanish
# criteria_max_home = 5  # Maximum of 5 people from home
# criteria_max_ucla = 10  # Maximum of 10 people from school
# criteria_hypertension = 3  # At least 3 people hypertension trained

# # List of priority people (PersonID)
# priority_people = [3, 7, 11, 150]  

# # List of already attended people (PersonID)
# already_attended = [5, 8, 15]

# # Randomly select people based on the criteria
# selected_people = set()
# num_selected = 0

# # Continue selection until the desired number is reached or no more eligible individuals
# while num_selected < 15 and (week1_sat.shape[0] - num_selected) >= (criteria_viet + criteria_max_home + criteria_max_ucla + criteria_hypertension):
#     # Fluent or Conversational in Spanish
#     fluent_or_conversational = week1_sat[week1_sat['SpanishProficiency'].isin(['Yes, I am fluent', 'Yes, but conversational'])]
#     selected_people.update(fluent_or_conversational.sample(min(criteria_spanish, len(fluent_or_conversational))).index)

#     # Fluent or Conversational in Vietnamese
#     fluent_or_conversational = week1_sat[week1_sat['VietnameseProficiency'].isin(['Yes, I am fluent', 'Yes, but conversational'])]
#     selected_people.update(fluent_or_conversational.sample(min(criteria_spanish, len(fluent_or_conversational))).index)
    
#     # Maximum of 5 people living at home
#     from_home = week1_sat[week1_sat['Do you need a ride from UCLA?'] == 'No, I can provide my own ride.']
#     selected_people.update(from_home.sample(min(criteria_max_home, len(from_home))).index)

#     # Maximum of 10 people living at school
#     from_ucla = week1_sat[week1_sat['Do you need a ride from UCLA?'] == 'Yes']
#     selected_people.update(from_school.sample(min(criteria_max_ucla, len(from_school))).index)

#     # At least 3 people hypertension trained
#     hypertension_trained = week1_sat[week1_sat['Are you Hypertension trained?'] == True]
#     selected_people.update(hypertension_trained.sample(max(0, criteria_hypertension - len(selected_people))).index)

#     # Update the count of selected people
#     num_selected = len(selected_people)

# # Convert the set to a list and truncate if necessary
# selected_people = list(selected_people)[:15]

# # Display the selected people
# selected_week1_sat = df.loc[selected_people]
# print(selected_week1_sat)

# %%
# og df = week1_sat

# new empty df with the same columns as the og df
# week1_sat_invites = pd.DataFrame(columns=week1_sat.columns)

# # function to select people for langauge and hypertension and move to new df
# def select_volunteers(row):
#     global week1_sat, week1_sat_invites
    
#     vietnamese_proficiency = row['Do you speak Vietnamese?']
#     hypertension_trained = row['Are you Hypertension trained?']
#     location = row['Do you need a ride from UCLA?']
    
#     # Check conditions

#     if vietnamese_proficiency in ['Yes, I am fluent', 'Yes, but conversational']:
#         if len(week1_sat_invites[week1_sat_invites['Do you speak Vietnamese?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
#             week1_sat_invites = week1_sat_invites._append(row, ignore_index=True)
#             week1_sat = week1_sat.drop(index=row.name)
            
#     else:
#         if hypertension_trained in ['Yes']:
#             if len(week1_sat_invites[week1_sat_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
#                 week1_sat_invites = week1_sat_invites._append(row, ignore_index=True)
#                 week1_sat = week1_sat.drop(index=row.name)  

# # function to randomly select remaining people to fill 10 people from ucla and 6 people from home
# def select_random(row):
#     global week1_sat, week1_sat_invites
    
#     location = row['Do you need a ride from UCLA?']
    
#     if location in ['Yes']:
#         if len(week1_sat_invites[week1_sat_invites['Do you need a ride from UCLA?'].isin(['Yes'])]) < 9:
#             week1_sat_invites = week1_sat_invites._append(row, ignore_index=True)
#             week1_sat = week1_sat.drop(index=row.name)
            
#     if location in ['No, I can provide my own ride.']:
#         if len(week1_sat_invites[week1_sat_invites['Do you need a ride from UCLA?'].isin(['No, I can provide my own ride.'])]) < 6:
#             week1_sat_invites = week1_sat_invites._append(row, ignore_index=True)
#             week1_sat = week1_sat.drop(index=row.name)
        
# # Loop through rows in the original dataframe
# for index, row in week1_sat.iterrows():
#     select_volunteers(row)

# for index, row in week1_sat.iterrows():
#     select_random(row)

# %%
# week1_sat_invites

# %%
# week1_sat

# %%
import pandas as pd
hs = pd.read_csv('./week1_hs_test.csv') #enter csv here
hs['Full Name'] = hs['Full Name'].str.upper()

agm = hs[hs['What Health Sites would you be available for? '].isin(['November 18 (Asian Garden Mall)', 'November 18 (Asian Garden Mall), November 19 (Santa Ana Plaza)'])]
sap = hs[hs['What Health Sites would you be available for? '].isin(['November 19 (Santa Ana Plaza)', 'November 18 (Asian Garden Mall), November 19 (Santa Ana Plaza)'])]
agm
# Out:
#               Timestamp                                          Full Name  \
# 0    11/9/2023 12:06:02                                          TAI VUONG
# 1    11/9/2023 22:47:36                                        KEVIN QUACH
# 2   11/13/2023 22:44:02                                    MATTHEW NGUYEN
# 3   11/14/2023 14:23:40                                       HATAN NGUYEN
# 4   11/15/2023 18:49:35                                         VY VY TRAN
# 5   11/15/2023 18:51:36                                       PRESTON PHAM
# 6   11/15/2023 18:51:45                                         AIDAN PHAM
# 7   11/15/2023 18:52:01                                          MEGAN VAN
# 8   11/15/2023 18:52:01                                        TINA NGUYEN
# 9    11/9/2023 14:58:02                             JESUS GONZALEZ RAMIREZ
# 10  11/12/2023 23:13:21                                        NATHAN TRAN
# 11  11/13/2023 19:51:24                                        BRIAN PHUNG
# 12  11/15/2023 21:57:11                                        JOANNE TRAN
# 13  11/16/2023 18:44:47                                   MI (MIMI) NGUYEN
# 14  11/16/2023 20:11:34  EMILY DO (IDK IF IT’S TOO LATE TO SIGN UP LOL ...
# 20  11/14/2023 19:26:59                                    ESMERALDA LOPEZ
# 23  11/15/2023 19:21:25                                       BRIAN PHUNG
# 24   11/9/2023 12:11:41                                     SAMANTHA VUONG
#
#     University ID #  Phone Number                     Email Year  \
# 0         206253368  657-263-6934         vtai2027@ucla.edu  1st
# 1         405795813    7074007988  santarosakevin@gmail.com  3rd
# 2         905799069    7146964388  mattnguyen03@g.ucla.edu   3rd
# 3         606155672    8582768014   hatannguyen44@gmail.com  1st
# 4         405944276    7146229109   vyvytran0210@g.ucla.edu  2nd
# 5         305759702    7142518730    Prestonpham1@gmail.com  3rd
# 6         406235019    7143319604   aphmabruin12@g.ucla.edu  1st
# 7         506200632    6262650824         mvan04@g.ucla.edu  1st
# 8         706155775    7143053640        tn650220@gmail.com  1st
# 9           5518139    8058036139       jagr2857@g.ucla.edu  4th
# 10        206293816    5595471506    nathantran559@ucla.edu  1st
# 11        606156799    7143482747    brianbruin2@g.ucla.edu  1st
# 12        705720821  714-833-3121    joannetran1@g.ucla.edu  3rd
# 13        806220681    4087240753      mitrangram@gmail.com  1st
# 14        806149656    7149105837     emilyvydo@g.ucla.edu   1st
# 20        105501082    8058148971       esmelgonz@gmail.com  4th
# 23        606156799    7143482747    brianbruin2@g.ucla.edu  1st
# 24        905533828    8184419081   Samanthav8502@gmail.com  4th
#
#        What Health Sites would you be available for?   \
# 0                     November 18 (Asian Garden Mall)
# 1                     November 18 (Asian Garden Mall)
# 2                     November 18 (Asian Garden Mall)
# 3                     November 18 (Asian Garden Mall)
# 4                     November 18 (Asian Garden Mall)
# 5                     November 18 (Asian Garden Mall)
# 6                     November 18 (Asian Garden Mall)
# 7                     November 18 (Asian Garden Mall)
# 8                     November 18 (Asian Garden Mall)
# 9   November 18 (Asian Garden Mall), November 19 (...
# 10  November 18 (Asian Garden Mall), November 19 (...
# 11  November 18 (Asian Garden Mall), November 19 (...
# 12                    November 18 (Asian Garden Mall)
# 13                    November 18 (Asian Garden Mall)
# 14                    November 18 (Asian Garden Mall)
# 20  November 18 (Asian Garden Mall), November 19 (...
# 23  November 18 (Asian Garden Mall), November 19 (...
# 24  November 18 (Asian Garden Mall), November 19 (...
#
#    Do you speak Vietnamese?    Do you speak Spanish?  \
# 0          Yes, I am fluent                       No
# 1   Yes, but conversational  Yes, but conversational
# 2   Yes, but conversational                       No
# 3                        No                       No
# 4          Yes, I am fluent                       No
# 5                        No                       No
# 6                        No  Yes, but conversational
# 7   Yes, but conversational                       No
# 8   Yes, but conversational                       No
# 9                        No         Yes, I am fluent
# 10                       No                       No
# 11  Yes, but conversational                       No
# 12         Yes, I am fluent  Yes, but conversational
# 13  Yes, but conversational  Yes, but conversational
# 14  Yes, but conversational                       No
# 20                       No         Yes, I am fluent
# 23  Yes, but conversational                       No
# 24                       No         Yes, I am fluent
#
#      Do you need a ride from UCLA?  \
# 0                              Yes
# 1                              Yes
# 2                              Yes
# 3                              Yes
# 4   No, I can provide my own ride.
# 5                              Yes
# 6                              Yes
# 7                              Yes
# 8                              Yes
# 9                              Yes
# 10                             Yes
# 11                             Yes
# 12                             Yes
# 13                             Yes
# 14                             Yes
# 20                             Yes
# 23                             Yes
# 24                             Yes
#
#                         Are you Hypertension trained?  \
# 0                                                 Yes
# 1                                                  No
# 2                                                 Yes
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                 No
# 13  No, but I have signed up for hypertension trai...
# 14  No, but I have signed up for hypertension trai...
# 20                                                Yes
# 23                                                Yes
# 24                                                 No
#
#                              Are you HIPAA Certified?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5   No, but I can send vchbruins@gmail.com the cer...
# 6   No, but I can send vchbruins@gmail.com the cer...
# 7   No, but I can send vchbruins@gmail.com the cer...
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13  No, but I can send vchbruins@gmail.com the cer...
# 14                                                Yes
# 20                                                Yes
# 23                                                Yes
# 24                                                Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13                                         Of course!
# 14                                                Yes
# 20                                                Yes
# 23                                                Yes
# 24                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 0                                               Small
# 1                               I already have a polo
# 2                               I already have a polo
# 3                               I already have a polo
# 4                                               Large
# 5                               I already have a polo
# 6                               I already have a polo
# 7                     I will purchase at office hours
# 8                     I will purchase at office hours
# 9                               I already have a polo
# 10                              I already have a polo
# 11                              I already have a polo
# 12                              I already have a polo
# 13                                              Small
# 14                              I already have a polo
# 20                              I already have a polo
# 23                              I already have a polo
# 24                              I already have a polo

# %%
sap
# Out:
#               Timestamp               Full Name  University ID # Phone Number  \
# 9    11/9/2023 14:58:02  JESUS GONZALEZ RAMIREZ          5518139   8058036139
# 10  11/12/2023 23:13:21             NATHAN TRAN        206293816   5595471506
# 11  11/13/2023 19:51:24             BRIAN PHUNG        606156799   7143482747
# 15   11/12/2023 0:09:03              NATALIE HO        206197198   6615234366
# 16  11/12/2023 17:22:05                NHI PHAM        805960957   9094889104
# 17  11/12/2023 19:48:04            ZACHARY LAMM        705606043   6506830822
# 18  11/13/2023 22:42:46                CINDY LY        105568100   4086428242
# 19   11/14/2023 2:05:30               TONY LUU         205620433   9099362086
# 20  11/14/2023 19:26:59         ESMERALDA LOPEZ        105501082   8058148971
# 21  11/15/2023 18:47:02             MAI-KHOI VU        506223676   7142069772
# 22  11/15/2023 18:50:30            ZACHARY LAMM        705606043   6506830822
# 23  11/15/2023 19:21:25            BRIAN PHUNG         606156799   7143482747
# 24   11/9/2023 12:11:41          SAMANTHA VUONG        905533828   8184419081
# 25  11/16/2023 17:19:41            SANDRA HOANG        606228353   7145150890
#
#                       Email Year  \
# 9       jagr2857@g.ucla.edu  4th
# 10   nathantran559@ucla.edu  1st
# 11   brianbruin2@g.ucla.edu  1st
# 15     natalieho11@ucla.edu  1st
# 16       nhip615@g.ucla.edu  2nd
# 17        zxlamm@g.ucla.edu  4th
# 18      cindyly648@ucla.edu  4th
# 19      Luut2002@g.ucla.edu  4th
# 20      esmelgonz@gmail.com  4th
# 21          mkvu@g.ucla.edu  1st
# 22        zxlamm@g.ucla.edu  4th
# 23   brianbruin2@g.ucla.edu  1st
# 24  Samanthav8502@gmail.com  4th
# 25  sandrahoang1@g.ucla.edu  1st
#
#        What Health Sites would you be available for?   \
# 9   November 18 (Asian Garden Mall), November 19 (...
# 10  November 18 (Asian Garden Mall), November 19 (...
# 11  November 18 (Asian Garden Mall), November 19 (...
# 15                      November 19 (Santa Ana Plaza)
# 16                      November 19 (Santa Ana Plaza)
# 17                      November 19 (Santa Ana Plaza)
# 18                      November 19 (Santa Ana Plaza)
# 19                      November 19 (Santa Ana Plaza)
# 20  November 18 (Asian Garden Mall), November 19 (...
# 21                      November 19 (Santa Ana Plaza)
# 22                      November 19 (Santa Ana Plaza)
# 23  November 18 (Asian Garden Mall), November 19 (...
# 24  November 18 (Asian Garden Mall), November 19 (...
# 25                      November 19 (Santa Ana Plaza)
#
#    Do you speak Vietnamese?    Do you speak Spanish?  \
# 9                        No         Yes, I am fluent
# 10                       No                       No
# 11  Yes, but conversational                       No
# 15                       No  Yes, but conversational
# 16  Yes, but conversational  Yes, but conversational
# 17                       No                       No
# 18         Yes, I am fluent                       No
# 19                       No                       No
# 20                       No         Yes, I am fluent
# 21  Yes, but conversational                       No
# 22                       No                       No
# 23  Yes, but conversational                       No
# 24                       No         Yes, I am fluent
# 25  Yes, but conversational                       No
#
#      Do you need a ride from UCLA?  \
# 9                              Yes
# 10                             Yes
# 11                             Yes
# 15                             Yes
# 16                             Yes
# 17                             Yes
# 18  No, I can provide my own ride.
# 19  No, I can provide my own ride.
# 20                             Yes
# 21  No, I can provide my own ride.
# 22                             Yes
# 23                             Yes
# 24                             Yes
# 25  No, I can provide my own ride.
#
#                         Are you Hypertension trained?  \
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 15  No, but I have signed up for hypertension trai...
# 16                                                Yes
# 17                                                Yes
# 18                                                 No
# 19                                                 No
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                 No
# 25                                                 No
#
#                              Are you HIPAA Certified?  \
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 15  No, but I can send vchbruins@gmail.com the cer...
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19  No, but I can send vchbruins@gmail.com the cer...
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25  No, but I can send vchbruins@gmail.com the cer...
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                         Of course!
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 9                               I already have a polo
# 10                              I already have a polo
# 11                              I already have a polo
# 15                                              Small
# 16                              I already have a polo
# 17                              I already have a polo
# 18                              I already have a polo
# 19                                             Medium
# 20                              I already have a polo
# 21                                              Small
# 22                              I already have a polo
# 23                              I already have a polo
# 24                              I already have a polo
# 25                              I already have a polo

# %%
# og df = hs

# new empty df with the same columns as the og df
agm_invites = pd.DataFrame(columns=agm.columns)

# function to select people for viet and hypertension and move to new df
def select_volunteers_agm(row):
    global agm, agm_invites
    
    vietnamese_proficiency = row['Do you speak Vietnamese?']
    hypertension_trained = row['Are you Hypertension trained?']
    location = row['Do you need a ride from UCLA?']
    
    # Check conditions

    if vietnamese_proficiency in ['Yes, I am fluent', 'Yes, but conversational']:
        if len(agm_invites[agm_invites['Do you speak Vietnamese?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
            agm_invites = agm_invites._append(row, ignore_index=True)
            agm = agm.drop(index=row.name)
            
    else:
        if hypertension_trained in ['Yes']:
            if len(agm_invites[agm_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
                agm_invites = agm_invites._append(row, ignore_index=True)
                agm = agm.drop(index=row.name)  


# function to randomly select remaining people to fill 10 people from ucla and 6 people from home for agm
def select_random_agm(row):
    global agm, agm_invites
    
    location = row['Do you need a ride from UCLA?']
    
    if location in ['Yes']:
        if len(agm_invites[agm_invites['Do you need a ride from UCLA?'].isin(['Yes'])]) < 9:
            agm_invites = agm_invites._append(row, ignore_index=True)
            agm = agm.drop(index=row.name)
            
    if location in ['No, I can provide my own ride.']:
        if len(agm_invites[agm_invites['Do you need a ride from UCLA?'].isin(['No, I can provide my own ride.'])]) < 6:
            agm_invites = agm_invites._append(row, ignore_index=True)
            agm = agm.drop(index=row.name)
    
    
    
    
# new empty df with the same columns as the og df
sap_invites = pd.DataFrame(columns=sap.columns)

# function to select people for spanish and hypertension and move to new df
def select_volunteers_sap(row):
    global sap, sap_invites
    
    spanish_proficiency = row['Do you speak Spanish?']
    hypertension_trained = row['Are you Hypertension trained?']
    location = row['Do you need a ride from UCLA?']
    
    # Check conditions

    if spanish_proficiency in ['Yes, I am fluent', 'Yes, but conversational']:
        if len(sap_invites[sap_invites['Do you speak Spanish?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
            sap_invites = sap_invites._append(row, ignore_index=True)
            sap = sap.drop(index=row.name)
            
    else:
        if hypertension_trained in ['Yes']:
            if len(sap_invites[sap_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
                sap_invites = sap_invites._append(row, ignore_index=True)
                sap = sap.drop(index=row.name)  
            
# function to randomly select remaining people to fill 10 people from ucla and 6 people from home for sap
def select_random_sap(row):
    global sap, sap_invites
    
    location = row['Do you need a ride from UCLA?']
    
    if location in ['Yes']:
        if len(sap_invites[sap_invites['Do you need a ride from UCLA?'].isin(['Yes'])]) < 9:
            sap_invites = sap_invites._append(row, ignore_index=True)
            sap = sap.drop(index=row.name)
            
    if location in ['No, I can provide my own ride.']:
        if len(sap_invites[sap_invites['Do you need a ride from UCLA?'].isin(['No, I can provide my own ride.'])]) < 6:
            sap_invites = sap_invites._append(row, ignore_index=True)
            sap = sap.drop(index=row.name)

# %%
# Loop through rows in the original dataframe for agm
for index, row in agm.iterrows():
    select_volunteers_agm(row)

for index, row in agm.iterrows():
    select_random_agm(row)

# %%
agm_invites
# Out:
#              Timestamp               Full Name University ID #  Phone Number  \
# 0   11/9/2023 12:06:02               TAI VUONG       206253368  657-263-6934
# 1   11/9/2023 22:47:36             KEVIN QUACH       405795813    7074007988
# 2  11/13/2023 22:44:02         MATTHEW NGUYEN        905799069    7146964388
# 3   11/9/2023 14:58:02  JESUS GONZALEZ RAMIREZ         5518139    8058036139
# 4  11/14/2023 14:23:40            HATAN NGUYEN       606155672    8582768014
# 5  11/15/2023 18:49:35              VY VY TRAN       405944276    7146229109
# 6  11/15/2023 18:51:36            PRESTON PHAM       305759702    7142518730
# 7  11/15/2023 18:51:45              AIDAN PHAM       406235019    7143319604
# 8  11/15/2023 18:52:01               MEGAN VAN       506200632    6262650824
# 9  11/15/2023 18:52:01             TINA NGUYEN       706155775    7143053640
#
#                       Email Year  \
# 0         vtai2027@ucla.edu  1st
# 1  santarosakevin@gmail.com  3rd
# 2  mattnguyen03@g.ucla.edu   3rd
# 3       jagr2857@g.ucla.edu  4th
# 4   hatannguyen44@gmail.com  1st
# 5   vyvytran0210@g.ucla.edu  2nd
# 6    Prestonpham1@gmail.com  3rd
# 7   aphmabruin12@g.ucla.edu  1st
# 8         mvan04@g.ucla.edu  1st
# 9        tn650220@gmail.com  1st
#
#       What Health Sites would you be available for?  Do you speak Vietnamese?  \
# 0                    November 18 (Asian Garden Mall)         Yes, I am fluent
# 1                    November 18 (Asian Garden Mall)  Yes, but conversational
# 2                    November 18 (Asian Garden Mall)  Yes, but conversational
# 3  November 18 (Asian Garden Mall), November 19 (...                       No
# 4                    November 18 (Asian Garden Mall)                       No
# 5                    November 18 (Asian Garden Mall)         Yes, I am fluent
# 6                    November 18 (Asian Garden Mall)                       No
# 7                    November 18 (Asian Garden Mall)                       No
# 8                    November 18 (Asian Garden Mall)  Yes, but conversational
# 9                    November 18 (Asian Garden Mall)  Yes, but conversational
#
#      Do you speak Spanish?   Do you need a ride from UCLA?  \
# 0                       No                             Yes
# 1  Yes, but conversational                             Yes
# 2                       No                             Yes
# 3         Yes, I am fluent                             Yes
# 4                       No                             Yes
# 5                       No  No, I can provide my own ride.
# 6                       No                             Yes
# 7  Yes, but conversational                             Yes
# 8                       No                             Yes
# 9                       No                             Yes
#
#   Are you Hypertension trained?  \
# 0                           Yes
# 1                            No
# 2                           Yes
# 3                           Yes
# 4                            No
# 5                            No
# 6                            No
# 7                            No
# 8                           Yes
# 9                           Yes
#
#                             Are you HIPAA Certified?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6  No, but I can send vchbruins@gmail.com the cer...
# 7  No, but I can send vchbruins@gmail.com the cer...
# 8  No, but I can send vchbruins@gmail.com the cer...
# 9                                                Yes
#
#   Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   Do you need to buy a polo? (One time purchase of $20)
# 0                                              Small
# 1                              I already have a polo
# 2                              I already have a polo
# 3                              I already have a polo
# 4                              I already have a polo
# 5                                              Large
# 6                              I already have a polo
# 7                              I already have a polo
# 8                    I will purchase at office hours
# 9                    I will purchase at office hours

# %%
# Loop through rows in the original dataframe for sap
for index, row in sap.iterrows():
    select_volunteers_sap(row)

for index, row in sap.iterrows():
    select_random_sap(row)

# %%
sap_invites
# Out:
#               Timestamp               Full Name University ID # Phone Number  \
# 0    11/9/2023 14:58:02  JESUS GONZALEZ RAMIREZ         5518139   8058036139
# 1   11/12/2023 23:13:21             NATHAN TRAN       206293816   5595471506
# 2   11/13/2023 19:51:24             BRIAN PHUNG       606156799   7143482747
# 3    11/12/2023 0:09:03              NATALIE HO       206197198   6615234366
# 4   11/12/2023 17:22:05                NHI PHAM       805960957   9094889104
# 5   11/12/2023 19:48:04            ZACHARY LAMM       705606043   6506830822
# 6   11/13/2023 22:42:46                CINDY LY       105568100   4086428242
# 7    11/14/2023 2:05:30               TONY LUU        205620433   9099362086
# 8   11/14/2023 19:26:59         ESMERALDA LOPEZ       105501082   8058148971
# 9   11/15/2023 18:47:02             MAI-KHOI VU       506223676   7142069772
# 10  11/15/2023 18:50:30            ZACHARY LAMM       705606043   6506830822
# 11  11/15/2023 19:21:25            BRIAN PHUNG        606156799   7143482747
# 12  11/16/2023 17:19:41            SANDRA HOANG       606228353   7145150890
#
#                       Email Year  \
# 0       jagr2857@g.ucla.edu  4th
# 1    nathantran559@ucla.edu  1st
# 2    brianbruin2@g.ucla.edu  1st
# 3      natalieho11@ucla.edu  1st
# 4        nhip615@g.ucla.edu  2nd
# 5         zxlamm@g.ucla.edu  4th
# 6       cindyly648@ucla.edu  4th
# 7       Luut2002@g.ucla.edu  4th
# 8       esmelgonz@gmail.com  4th
# 9           mkvu@g.ucla.edu  1st
# 10        zxlamm@g.ucla.edu  4th
# 11   brianbruin2@g.ucla.edu  1st
# 12  sandrahoang1@g.ucla.edu  1st
#
#        What Health Sites would you be available for?   \
# 0   November 18 (Asian Garden Mall), November 19 (...
# 1   November 18 (Asian Garden Mall), November 19 (...
# 2   November 18 (Asian Garden Mall), November 19 (...
# 3                       November 19 (Santa Ana Plaza)
# 4                       November 19 (Santa Ana Plaza)
# 5                       November 19 (Santa Ana Plaza)
# 6                       November 19 (Santa Ana Plaza)
# 7                       November 19 (Santa Ana Plaza)
# 8   November 18 (Asian Garden Mall), November 19 (...
# 9                       November 19 (Santa Ana Plaza)
# 10                      November 19 (Santa Ana Plaza)
# 11  November 18 (Asian Garden Mall), November 19 (...
# 12                      November 19 (Santa Ana Plaza)
#
#    Do you speak Vietnamese?    Do you speak Spanish?  \
# 0                        No         Yes, I am fluent
# 1                        No                       No
# 2   Yes, but conversational                       No
# 3                        No  Yes, but conversational
# 4   Yes, but conversational  Yes, but conversational
# 5                        No                       No
# 6          Yes, I am fluent                       No
# 7                        No                       No
# 8                        No         Yes, I am fluent
# 9   Yes, but conversational                       No
# 10                       No                       No
# 11  Yes, but conversational                       No
# 12  Yes, but conversational                       No
#
#      Do you need a ride from UCLA?  \
# 0                              Yes
# 1                              Yes
# 2                              Yes
# 3                              Yes
# 4                              Yes
# 5                              Yes
# 6   No, I can provide my own ride.
# 7   No, I can provide my own ride.
# 8                              Yes
# 9   No, I can provide my own ride.
# 10                             Yes
# 11                             Yes
# 12  No, I can provide my own ride.
#
#                         Are you Hypertension trained?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3   No, but I have signed up for hypertension trai...
# 4                                                 Yes
# 5                                                 Yes
# 6                                                  No
# 7                                                  No
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                 No
#
#                              Are you HIPAA Certified?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3   No, but I can send vchbruins@gmail.com the cer...
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7   No, but I can send vchbruins@gmail.com the cer...
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12  No, but I can send vchbruins@gmail.com the cer...
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                          Of course!
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 0                               I already have a polo
# 1                               I already have a polo
# 2                               I already have a polo
# 3                                               Small
# 4                               I already have a polo
# 5                               I already have a polo
# 6                               I already have a polo
# 7                                              Medium
# 8                               I already have a polo
# 9                                               Small
# 10                              I already have a polo
# 11                              I already have a polo
# 12                              I already have a polo

# %%
import pandas as pd
agm = pd.read_csv('W24 Week 2 Health Site Sign-Up.csv') #enter csv here
# CONSISTENT DIRECTORY PATH
agm['Full Name'] = agm['Full Name'].str.upper()

# agm = hs[hs['What Health Sites would you be available for? '].isin(['November 18 (Asian Garden Mall)', 'November 18 (Asian Garden Mall), November 19 (Santa Ana Plaza)'])]
# sap = hs[hs['What Health Sites would you be available for? '].isin(['November 19 (Santa Ana Plaza)', 'November 18 (Asian Garden Mall), November 19 (Santa Ana Plaza)'])]
agm
# Out:
#             Timestamp                Full Name  University ID #  \
# 0   1/9/2024 19:56:23               NICOLE TON        305674152
# 1   1/9/2024 19:56:26              HILLARY LEE        305958546
# 2   1/9/2024 19:56:48               HAYDEN KIM        205957188
# 3   1/9/2024 19:57:00                 EMILY DO        806149656
# 4   1/9/2024 19:57:29                MEGHAN LE        305597516
# 5   1/9/2024 19:57:40            MINH-ANH PHAM        105994017
# 6   1/9/2024 19:57:46                 NHI PHAM        805960957
# 7   1/9/2024 19:58:00               KELLY TRAN          5512444
# 8   1/9/2024 19:58:37              CELINE KHUU          5506037
# 9   1/9/2024 19:59:44              VINCENT CAO        605919290
# 10  1/9/2024 20:00:09              EVONNE CHAU        905809426
# 11  1/9/2024 20:01:25            KELLY NGUYEN         305736522
# 12  1/9/2024 20:01:37             NEHA CHANDRA        805512143
# 13  1/9/2024 20:01:41            ALYSON NGUYEN        806159056
# 14  1/9/2024 20:02:04               BRANDON HO        705999385
# 15  1/9/2024 20:02:36              CHLOE DUONG        606256303
# 16  1/9/2024 20:10:40             ALVIN NGUYEN          5599989
# 17  1/9/2024 20:21:06                 KAYLA LE        506238220
# 18  1/9/2024 20:44:09              NATALIE BUI        406169972
# 19  1/9/2024 21:04:12                  TIFFANY        506174789
# 20  1/9/2024 22:13:33  JAZMIN ALEXANDRA CHAVEZ        806139695
# 21  1/9/2024 23:05:25              NATHAN TRAN        206293816
#
#      Phone Number                     Email Year Do you speak Vietnamese?  \
# 0      7142779093      nicolenton@gmail.com  3rd  Yes, but conversational
# 1      6262675243         hillaryl@ucla.edu  2nd  Yes, but conversational
# 2      9495659041      haydenkim@g.ucla.edu  2nd                       No
# 3      7149105837     emilyvydo@g.ucla.edu   1st  Yes, but conversational
# 4      7149305830     meghanle77@g.ucla.edu  4th  Yes, but conversational
# 5   408 806-2999      minhanhp26@g.ucla.edu  2nd         Yes, I am fluent
# 6      9094889104        nhip615@g.ucla.edu  2nd  Yes, but conversational
# 7      9093447083         kptran20@ucla.edu  4th  Yes, but conversational
# 8      8182945081    celinekhuu9@g.ucla.edu  4th         Yes, I am fluent
# 9      9168237444    vincent.d.cao@ucla.edu  2nd         Yes, I am fluent
# 10     6618256982     evonne2002@g.ucla.edu  3rd         Yes, I am fluent
# 11     6268936602   kellykim2021@gmail.com   3rd         Yes, I am fluent
# 12     9163371808  nehachandra531@gmail.com  4th                       No
# 13     6695006118     alysonnguyen@ucla.edu  1st         Yes, I am fluent
# 14     7252447329  brandonho2018@g.ucla.edu  2nd                       No
# 15     9494633715          Cduong8@ucla.edu  1st                       No
# 16     9517104059      Alvinnguyen@ucla.edu  4th  Yes, but conversational
# 17     7143091753      kaylaghle@g.ucla.edu  1st  Yes, but conversational
# 18     9095365563   nataliebui05@g.ucla.edu  1st         Yes, I am fluent
# 19     9096629615    tiffanybui88@gmail.com  1st  Yes, but conversational
# 20     7147603752   jazminchavez@g.ucla.edu  1st                       No
# 21     5595471506    nathantran559@ucla.edu  1st                       No
#
#       Do you speak Spanish?   Do you need a ride from UCLA?  \
# 0   Yes, but conversational  No, I can provide my own ride.
# 1                        No                             Yes
# 2                        No                             Yes
# 3                        No                             Yes
# 4   Yes, but conversational  No, I can provide my own ride.
# 5                        No                             Yes
# 6   Yes, but conversational                             Yes
# 7                        No                             Yes
# 8                        No                             Yes
# 9   Yes, but conversational                             Yes
# 10                       No                             Yes
# 11                       No  No, I can provide my own ride.
# 12  Yes, but conversational                             Yes
# 13                       No                             Yes
# 14  Yes, but conversational                             Yes
# 15                       No                             Yes
# 16                       No                             Yes
# 17                       No                             Yes
# 18                       No                             Yes
# 19                       No  No, I can provide my own ride.
# 20         Yes, I am fluent                             Yes
# 21                       No                             Yes
#
#                         Are you Hypertension trained?  \
# 0                                                  No
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12  No, but I have signed up for hypertension trai...
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                 No
# 18                                                 No
# 19                                                 No
# 20  No, but I have signed up for hypertension trai...
# 21                                                Yes
#
#                              Are you HIPAA Certified?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12  No, but I can send vchbruins@gmail.com the cer...
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                          Of course!
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                          Of course!
# 10                                                Yes
# 11                                                Yes
# 12                                         Of course!
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 0                               I already have a polo
# 1                               I already have a polo
# 2                               I already have a polo
# 3                               I already have a polo
# 4                               I already have a polo
# 5                               I already have a polo
# 6                               I already have a polo
# 7                               I already have a polo
# 8                               I already have a polo
# 9                               I already have a polo
# 10                              I already have a polo
# 11                              I already have a polo
# 12                                             Medium
# 13                              I already have a polo
# 14                              I already have a polo
# 15                              I already have a polo
# 16                              I already have a polo
# 17                                              Small
# 18                                              Small
# 19                              I already have a polo
# 20                                             Medium
# 21                              I already have a polo

# %%
agm_invites = pd.DataFrame(columns=agm.columns)

# function to select people for viet and hypertension and move to new df
def select_volunteers_agm(row):
    global agm, agm_invites
    
    vietnamese_proficiency = row['Do you speak Vietnamese?']
    hypertension_trained = row['Are you Hypertension trained?']
    location = row['Do you need a ride from UCLA?']
    
    # Check conditions

    if vietnamese_proficiency in ['Yes, I am fluent', 'Yes, but conversational']:
        if len(agm_invites[agm_invites['Do you speak Vietnamese?'].isin(['Yes, I am fluent', 'Yes, but conversational'])]) < 3: 
            agm_invites = agm_invites._append(row, ignore_index=True)
            agm = agm.drop(index=row.name)
            
    else:
        if hypertension_trained in ['Yes']:
            if len(agm_invites[agm_invites['Are you Hypertension trained?'].isin(['Yes'])]) < 3:
                agm_invites = agm_invites._append(row, ignore_index=True)
                agm = agm.drop(index=row.name)  


# function to randomly select remaining people to fill 10 people from ucla and 6 people from home for agm
def select_random_agm(row):
    global agm, agm_invites
    
    location = row['Do you need a ride from UCLA?']
    
    if location in ['Yes']:
        if len(agm_invites[agm_invites['Do you need a ride from UCLA?'].isin(['Yes'])]) < 10:
            agm_invites = agm_invites._append(row, ignore_index=True)
            agm = agm.drop(index=row.name)
            
    if location in ['No, I can provide my own ride.']:
        if len(agm_invites[agm_invites['Do you need a ride from UCLA?'].isin(['No, I can provide my own ride.'])]) < 6:
            agm_invites = agm_invites._append(row, ignore_index=True)
            agm = agm.drop(index=row.name)

# %%
for index, row in agm.iterrows():
    select_volunteers_agm(row)

for index, row in agm.iterrows():
    select_random_agm(row)

# %%
agm_invites
# Out:
#             Timestamp      Full Name University ID #   Phone Number  \
# 0   1/9/2024 19:56:23     NICOLE TON       305674152     7142779093
# 1   1/9/2024 19:56:26    HILLARY LEE       305958546     6262675243
# 2   1/9/2024 19:56:48     HAYDEN KIM       205957188     9495659041
# 3   1/9/2024 19:57:00       EMILY DO       806149656     7149105837
# 4   1/9/2024 19:57:29      MEGHAN LE       305597516     7149305830
# 5   1/9/2024 19:57:40  MINH-ANH PHAM       105994017  408 806-2999
# 6   1/9/2024 19:57:46       NHI PHAM       805960957     9094889104
# 7   1/9/2024 19:58:00     KELLY TRAN         5512444     9093447083
# 8   1/9/2024 19:58:37    CELINE KHUU         5506037     8182945081
# 9   1/9/2024 19:59:44    VINCENT CAO       605919290     9168237444
# 10  1/9/2024 20:00:09    EVONNE CHAU       905809426     6618256982
# 11  1/9/2024 20:01:25  KELLY NGUYEN        305736522     6268936602
# 12  1/9/2024 20:01:37   NEHA CHANDRA       805512143     9163371808
# 13  1/9/2024 21:04:12        TIFFANY       506174789     9096629615
#
#                        Email Year Do you speak Vietnamese?  \
# 0       nicolenton@gmail.com  3rd  Yes, but conversational
# 1          hillaryl@ucla.edu  2nd  Yes, but conversational
# 2       haydenkim@g.ucla.edu  2nd                       No
# 3      emilyvydo@g.ucla.edu   1st  Yes, but conversational
# 4      meghanle77@g.ucla.edu  4th  Yes, but conversational
# 5      minhanhp26@g.ucla.edu  2nd         Yes, I am fluent
# 6         nhip615@g.ucla.edu  2nd  Yes, but conversational
# 7          kptran20@ucla.edu  4th  Yes, but conversational
# 8     celinekhuu9@g.ucla.edu  4th         Yes, I am fluent
# 9     vincent.d.cao@ucla.edu  2nd         Yes, I am fluent
# 10     evonne2002@g.ucla.edu  3rd         Yes, I am fluent
# 11   kellykim2021@gmail.com   3rd         Yes, I am fluent
# 12  nehachandra531@gmail.com  4th                       No
# 13    tiffanybui88@gmail.com  1st  Yes, but conversational
#
#       Do you speak Spanish?   Do you need a ride from UCLA?  \
# 0   Yes, but conversational  No, I can provide my own ride.
# 1                        No                             Yes
# 2                        No                             Yes
# 3                        No                             Yes
# 4   Yes, but conversational  No, I can provide my own ride.
# 5                        No                             Yes
# 6   Yes, but conversational                             Yes
# 7                        No                             Yes
# 8                        No                             Yes
# 9   Yes, but conversational                             Yes
# 10                       No                             Yes
# 11                       No  No, I can provide my own ride.
# 12  Yes, but conversational                             Yes
# 13                       No  No, I can provide my own ride.
#
#                         Are you Hypertension trained?  \
# 0                                                  No
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12  No, but I have signed up for hypertension trai...
# 13                                                 No
#
#                              Are you HIPAA Certified?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12  No, but I can send vchbruins@gmail.com the cer...
# 13                                                Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 0                                          Of course!
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                          Of course!
# 10                                                Yes
# 11                                                Yes
# 12                                         Of course!
# 13                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 0                               I already have a polo
# 1                               I already have a polo
# 2                               I already have a polo
# 3                               I already have a polo
# 4                               I already have a polo
# 5                               I already have a polo
# 6                               I already have a polo
# 7                               I already have a polo
# 8                               I already have a polo
# 9                               I already have a polo
# 10                              I already have a polo
# 11                              I already have a polo
# 12                                             Medium
# 13                              I already have a polo

# %%
agm
# Out:
#             Timestamp                Full Name  University ID # Phone Number  \
# 13  1/9/2024 20:01:41            ALYSON NGUYEN        806159056   6695006118
# 14  1/9/2024 20:02:04               BRANDON HO        705999385   7252447329
# 15  1/9/2024 20:02:36              CHLOE DUONG        606256303   9494633715
# 16  1/9/2024 20:10:40             ALVIN NGUYEN          5599989   9517104059
# 17  1/9/2024 20:21:06                 KAYLA LE        506238220   7143091753
# 18  1/9/2024 20:44:09              NATALIE BUI        406169972   9095365563
# 20  1/9/2024 22:13:33  JAZMIN ALEXANDRA CHAVEZ        806139695   7147603752
# 21  1/9/2024 23:05:25              NATHAN TRAN        206293816   5595471506
#
#                        Email Year Do you speak Vietnamese?  \
# 13     alysonnguyen@ucla.edu  1st         Yes, I am fluent
# 14  brandonho2018@g.ucla.edu  2nd                       No
# 15          Cduong8@ucla.edu  1st                       No
# 16      Alvinnguyen@ucla.edu  4th  Yes, but conversational
# 17      kaylaghle@g.ucla.edu  1st  Yes, but conversational
# 18   nataliebui05@g.ucla.edu  1st         Yes, I am fluent
# 20   jazminchavez@g.ucla.edu  1st                       No
# 21    nathantran559@ucla.edu  1st                       No
#
#       Do you speak Spanish? Do you need a ride from UCLA?  \
# 13                       No                           Yes
# 14  Yes, but conversational                           Yes
# 15                       No                           Yes
# 16                       No                           Yes
# 17                       No                           Yes
# 18                       No                           Yes
# 20         Yes, I am fluent                           Yes
# 21                       No                           Yes
#
#                         Are you Hypertension trained?  \
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                 No
# 18                                                 No
# 20  No, but I have signed up for hypertension trai...
# 21                                                Yes
#
#    Are you HIPAA Certified?  \
# 13                      Yes
# 14                      Yes
# 15                      Yes
# 16                      Yes
# 17                      Yes
# 18                      Yes
# 20                      Yes
# 21                      Yes
#
#    Do you acknowledge that you must have a negative COVID test within 7 days of this event?  \
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 20                                                Yes
# 21                                                Yes
#
#    Do you need to buy a polo? (One time purchase of $20)
# 13                              I already have a polo
# 14                              I already have a polo
# 15                              I already have a polo
# 16                              I already have a polo
# 17                                              Small
# 18                                              Small
# 20                                             Medium
# 21                              I already have a polo
